# %%
import pandas as pd

# %%
df = pd.read_json('data/1.json')

# %%
df
# Out:
#                                                                   payload  \
# allShortcutsEnabled                                                 False
# blob                    {'rawLines': ['[ {', '  "match_id" : 9880,', '...
# copilotInfo                                                          None
# csrf_tokens             {'/statsbomb/open-data/branches': {'post': 'yB...
# currentUser                                                          None
# fileTree                {'data/matches/11': {'items': [{'name': '1.jso...
# fileTreeProcessingTime                                           12.31432
# foldersToFetch                                                         []
# path                                               data/matches/11/1.json
# reducedMotionEnabled                                                 None
# refInfo                 {'name': 'master', 'listCacheKey': 'v0:1690544...
# repo                    {'id': 136174015, 'defaultBranch': 'master', '...
# ...
